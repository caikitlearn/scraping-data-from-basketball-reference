# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
from get_all_players import get_data
from get_player_table import get_table

pd.options.display.max_columns=None

# %%
all_players=get_data()
# do something with list_of_all_players

# %%
# picking a *random* player
i=4033
all_players.iloc[4033]
# Out:
# Player                      Klay Thompson
# From                                 2012
# To                                   2018
# Pos                                   G-F
# Ht                                    6-7
# Wt                                    215
# Birth Date               February 8, 1990
# Colleges      Washington State University
# url             /players/t/thompkl01.html
# is_active                            True
# in_hof                              False
# Name: 4033, dtype: object

# %%
html=requests.get('https://www.basketball-reference.com'+all_players['url'].iloc[i]).content
klay=BeautifulSoup(html,'lxml')

# %%
# Per Game: div_per_game
get_table(klay,'div_per_game')
# Out:
#     Season Age   Tm   Lg Pos    G   GS    MP   FG   FGA   FG%   3P  3PA   3P%  \
# 0  2011-12  21  GSW  NBA  SG   66   29  24.4  4.8  10.9  .443  1.7  4.1  .414
# 1  2012-13  22  GSW  NBA  SG   82   82  35.8  6.2  14.7  .422  2.6  6.4  .401
# 2  2013-14  23  GSW  NBA  SG   81   81  35.4  6.9  15.5  .444  2.8  6.6  .417
# 3  2014-15  24  GSW  NBA  SG   77   77  31.9  7.8  16.9  .463  3.1  7.1  .439
# 4  2015-16  25  GSW  NBA  SG   80   80  33.3  8.1  17.3  .470  3.5  8.1  .425
# 5  2016-17  26  GSW  NBA  SG   78   78  34.0  8.3  17.6  .468  3.4  8.3  .414
# 6  2017-18  27  GSW  NBA  SG   73   73  34.3  7.9  16.1  .488  3.1  7.1  .440
# 7   Career           NBA      537  500  32.9  7.2  15.7  .458  2.9  6.9  .422
#
#     2P  2PA   2P%  eFG%   FT  FTA   FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  \
# 0  3.1  6.8  .460  .520  1.2  1.4  .868  0.4  2.1  2.4  2.0  0.7  0.3  1.6
# 1  3.6  8.3  .437  .509  1.6  1.9  .841  0.4  3.3  3.7  2.2  1.0  0.5  1.9
# ...

# %%
# Totals: div_totals
get_table(klay,'div_totals')
# Out:
#     Season Age   Tm   Lg Pos    G   GS     MP    FG   FGA   FG%    3P   3PA  \
# 0  2011-12  21  GSW  NBA  SG   66   29   1608   318   718  .443   111   268
# 1  2012-13  22  GSW  NBA  SG   82   82   2936   508  1205  .422   211   526
# 2  2013-14  23  GSW  NBA  SG   81   81   2868   559  1259  .444   223   535
# 3  2014-15  24  GSW  NBA  SG   77   77   2455   602  1299  .463   239   545
# 4  2015-16  25  GSW  NBA  SG   80   80   2666   651  1386  .470   276   650
# 5  2016-17  26  GSW  NBA  SG   78   78   2649   644  1376  .468   268   647
# 6  2017-18  27  GSW  NBA  SG   73   73   2506   575  1178  .488   229   520
# 7   Career           NBA      537  500  17688  3857  8421  .458  1557  3691
#
#     3P%    2P   2PA   2P%  eFG%    FT   FTA   FT%  ORB   DRB   TRB   AST  STL  \
# 0  .414   207   450  .460  .520    79    91  .868   24   137   161   133   49
# 1  .401   297   679  .437  .509   132   157  .841   32   274   306   183   86
# ...

# %%
# Per 36 Minutes: div_per_minute
get_table(klay,'div_per_minute')
# Out:
#     Season Age   Tm   Lg Pos    G   GS     MP   FG   FGA   FG%   3P  3PA  \
# 0  2011-12  21  GSW  NBA  SG   66   29   1608  7.1  16.1  .443  2.5  6.0
# 1  2012-13  22  GSW  NBA  SG   82   82   2936  6.2  14.8  .422  2.6  6.4
# 2  2013-14  23  GSW  NBA  SG   81   81   2868  7.0  15.8  .444  2.8  6.7
# 3  2014-15  24  GSW  NBA  SG   77   77   2455  8.8  19.0  .463  3.5  8.0
# 4  2015-16  25  GSW  NBA  SG   80   80   2666  8.8  18.7  .470  3.7  8.8
# 5  2016-17  26  GSW  NBA  SG   78   78   2649  8.8  18.7  .468  3.6  8.8
# 6  2017-18  27  GSW  NBA  SG   73   73   2506  8.3  16.9  .488  3.3  7.5
# 7   Career           NBA      537  500  17688  7.9  17.1  .458  3.2  7.5
#
#     3P%   2P   2PA   2P%   FT  FTA   FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  \
# 0  .414  4.6  10.1  .460  1.8  2.0  .868  0.5  3.1  3.6  3.0  1.1  0.4  2.3
# 1  .401  3.6   8.3  .437  1.6  1.9  .841  0.4  3.4  3.8  2.2  1.1  0.6  1.9
# 2  .417  4.2   9.1  .464  1.8  2.3  .795  0.5  2.6  3.1  2.3  0.9  0.5  1.7
# ...

# %%
# Per 100 Poss: div_per_poss
get_table(klay,'div_per_poss')
# Out:
#     Season Age   Tm   Lg Pos    G   GS     MP    FG   FGA   FG%   3P   3PA  \
# 0  2011-12  21  GSW  NBA  SG   66   29   1608  10.3  23.2  .443  3.6   8.7
# 1  2012-13  22  GSW  NBA  SG   82   82   2936   8.8  20.9  .422  3.7   9.1
# 2  2013-14  23  GSW  NBA  SG   81   81   2868   9.7  21.9  .444  3.9   9.3
# 3  2014-15  24  GSW  NBA  SG   77   77   2455  12.0  25.8  .463  4.8  10.8
# 4  2015-16  25  GSW  NBA  SG   80   80   2666  11.8  25.1  .470  5.0  11.8
# 5  2016-17  26  GSW  NBA  SG   78   78   2649  11.7  25.0  .468  4.9  11.8
# 6  2017-18  27  GSW  NBA  SG   73   73   2506  11.1  22.7  .488  4.4  10.0
# 7   Career           NBA      537  500  17688  10.8  23.5  .458  4.3  10.3
#
#     3P%   2P   2PA   2P%   FT  FTA   FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  \
# 0  .414  6.7  14.5  .460  2.6  2.9  .868  0.8  4.4  5.2  4.3  1.6  0.6  3.3
# 1  .401  5.1  11.8  .437  2.3  2.7  .841  0.6  4.7  5.3  3.2  1.5  0.8  2.7
# ...

# %%
# Advanced: div_advanced
get_table(klay,'div_per_game')
# Out:
#     Season Age   Tm   Lg Pos    G   GS    MP   FG   FGA   FG%   3P  3PA   3P%  \
# 0  2011-12  21  GSW  NBA  SG   66   29  24.4  4.8  10.9  .443  1.7  4.1  .414
# 1  2012-13  22  GSW  NBA  SG   82   82  35.8  6.2  14.7  .422  2.6  6.4  .401
# 2  2013-14  23  GSW  NBA  SG   81   81  35.4  6.9  15.5  .444  2.8  6.6  .417
# 3  2014-15  24  GSW  NBA  SG   77   77  31.9  7.8  16.9  .463  3.1  7.1  .439
# 4  2015-16  25  GSW  NBA  SG   80   80  33.3  8.1  17.3  .470  3.5  8.1  .425
# 5  2016-17  26  GSW  NBA  SG   78   78  34.0  8.3  17.6  .468  3.4  8.3  .414
# 6  2017-18  27  GSW  NBA  SG   73   73  34.3  7.9  16.1  .488  3.1  7.1  .440
# 7   Career           NBA      537  500  32.9  7.2  15.7  .458  2.9  6.9  .422
#
#     2P  2PA   2P%  eFG%   FT  FTA   FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  \
# 0  3.1  6.8  .460  .520  1.2  1.4  .868  0.4  2.1  2.4  2.0  0.7  0.3  1.6
# 1  3.6  8.3  .437  .509  1.6  1.9  .841  0.4  3.3  3.7  2.2  1.0  0.5  1.9
# ...

# %%
# does not work for other tables as of now
